# %%
import pandas as pd
import numpy as np
from statsmodels.duration.hazard_regression import PHReg

import re

# %matplotlib inline

import seaborn as sns
sns.set_style('white')

# %%
#Lifelines stuff
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
from lifelines.statistics import multivariate_logrank_test
from lifelines.statistics import pairwise_logrank_test

kmf = KaplanMeierFitter()

# %%
ups = pd.read_csv('./Data/ups.txt', sep='\t', index_col=0)

# %%
#Filtering Steps
ups['age'] = ups['Age recode with single ages and 85+'].map(lambda x: int(re.match('[0-9]+', x).group(0)))

#Survival DF
filt_ups = ups[ups['Survival months'] != 'Unknown']
filt_ups['Survival_months'] = filt_ups['Survival months'].astype(int)
filt_ups['censored'] = filt_ups['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})

# %%
ups.age.plot(kind='hist')
plt.xlabel('Age in Years')
plt.title('Age Distribution of ' + str(len(ups.age)) + ' UPS patients')
plt.xlim([15, 85])
# Out:
# (15, 85)

# %%
ups['Year of diagnosis'].plot(kind='hist')

plt.xlabel('Year of Diagnosis')
plt.title('Year of Diagnosis Distribution of ' + str(len(ups.age)) + ' UPS patients')

plt.xlim([1975, 2013])
# Out:
# (1975, 2013)

# %%
ups.Sex.value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.title('Sex Distribution')

# %%
def mapLocation(line):
    line = line.lower()
    if 'lower limb' in line:
        return 'Lower Extremity'
    elif ('upr limb' in line) | ('upper limb' in line):
        return 'Upper Extremity'
    elif ('neck' in line) | ('face' in line) | ('ear' in line):
        return 'Head and Neck'
    elif ('thorax' in line):
        return 'Thorax'
    elif 'lung' in line:
        return 'Lung'
    elif ('pelvis' in line) | ('pelvic' in line):
        return 'Pelvis'
    elif 'retroperitoneum' in line:
        return 'Retroperitoneum'
    elif 'trunk' in line:
        return 'Trunk'
    elif ('abdomen' in line) | ('peritoneum' in line):
        return 'Abdomen'
    else:
        return 'Other'

# %%
location_vc = ups['Primary Site - labeled'].map(mapLocation).value_counts()

# %%
labels = location_vc.index.values
fracs = location_vc.values
colors = sns.color_palette("hls", 10)

pie(fracs, labels=labels, shadow=True, colors=colors, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Location of ' + str(sum(fracs)) + ' UPS')

# %%
grade_vc = ups.Grade.value_counts().drop('Unknown')

grade_vc.plot(kind='barh')
plt.title('Grading of ' + str(grade_vc.sum()) + ' UPS')

# %%
combined_t_stage = pd.concat([ups['Derived AJCC T, 7th ed (2010+)'].value_counts(),\
            ups['Derived AJCC T, 6th ed (2004+)'].value_counts(),\
           ups['T value - based on AJCC 3rd (1988-2003)'].value_counts()], axis=1).fillna(0)

# %%
combined_t_stage = pd.concat([ups['Derived AJCC T, 7th ed (2010+)'].value_counts(),\
            ups['Derived AJCC T, 6th ed (2004+)'].value_counts(),\
           ups['T value - based on AJCC 3rd (1988-2003)'].value_counts()], axis=1).fillna(0)

# %%
combined_t_stage = combined_t_stage.sum(axis=1)
combined_t_stage = combined_t_stage.drop(['Blank(s)', 'Recode scheme not yet available', 'TX', 'TXa', 'TXc', 'T0'])
combined_t_stage.index = combined_t_stage.index.map(lambda x: re.match('T[0-9]', x).group(0))

# %%
combined_t_stage.groupby(level=0).sum().plot(kind='bar')
plt.xticks(rotation=0)

plt.title('T Stage of ' + str(int(combined_t_stage.sum())) + ' UPS')
plt.xlabel('T Stage')

# %%
radiation_vc = ups['Radiation sequence with surgery'].value_counts().drop(['Intraoperative rad with other rad before/after surgery', 'Sequence unknown, but both were given', 'Intraoperative radiation'])

# %%
ups.set_index('SEER historic stage A').ix['Distant']
# Out:
#                                 ICD-O-3 Hist/behav, malignant  \
# SEER historic stage A
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# ...                                                       ...
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                8830/3: Malignant fibrous histiocytoma
# Distant                                            C48.0-Retroperitoneum
# Distant                                            C48.0-Retroperitoneum
# Distant                                            C48.0-Retroperitoneum
# Distant                                     C44.4-Skin of scalp and neck
# Distant                                            C48.0-Retroperitoneum
# Distant                C49.9-Conn, subcutaneous and other soft tissue...
# Distant                 C49.5-Conn, subcutaneous, other soft tis: pelvis
# Distant                C49.0-Conn, subcutaneous, other soft tis: head...
# Distant                                           C38.3-Mediastinum, NOS
# Distant                C41.4-Pelvic bones, sacrum, coccyx and associa...
# Distant                C49.4-Conn, subcutaneous, other soft tis: abdomen
# Distant                C49.6-Conn, subcutaneous, other soft tis: trun...
# Distant                                            C48.0-Retroperitoneum
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C40.0-Long bones: upper limb, scapula, and ass...
# Distant                                           C38.3-Mediastinum, NOS
# Distant                 C49.3-Conn, subcutaneous, other soft tis: thorax
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                 C49.3-Conn, subcutaneous, other soft tis: thorax
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                                            C48.0-Retroperitoneum
# Distant                C49.8-Overlap conn, subcutaneous, and other so...
# Distant                C40.2-Long bones of lower limb and associated ...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                                                  C41.9-Bone, NOS
# Distant                                            C48.0-Retroperitoneum
# ...                                                                  ...
# Distant                C40.2-Long bones of lower limb and associated ...
# Distant                                            C48.0-Retroperitoneum
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                                            C48.0-Retroperitoneum
# Distant                                                  C44.9-Skin, NOS
# Distant                C49.9-Conn, subcutaneous and other soft tissue...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                                  C50.1-Central portion of breast
# Distant                C40.2-Long bones of lower limb and associated ...
# Distant                                                    C33.9-Trachea
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C49.6-Conn, subcutaneous, other soft tis: trun...
# Distant                C49.1-Conn, subcutaneous, other soft tis: upr ...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                 C49.3-Conn, subcutaneous, other soft tis: thorax
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                 C49.3-Conn, subcutaneous, other soft tis: thorax
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                C49.4-Conn, subcutaneous, other soft tis: abdomen
# Distant                 C49.3-Conn, subcutaneous, other soft tis: thorax
# Distant                C49.2-Conn, subcutaneous, other soft tis: lowe...
# Distant                 C49.5-Conn, subcutaneous, other soft tis: pelvis
# Distant                C49.1-Conn, subcutaneous, other soft tis: upr ...
# Distant                                                    C16.4-Pylorus
# Distant                                            C48.0-Retroperitoneum
# Distant                 C49.5-Conn, subcutaneous, other soft tis: pelvis
# Distant                                            98
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# Distant                                      Blank(s)
# ...                                               ...
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            99
# Distant                                            98
# Distant                                            01
# Distant                                            98
# Distant                                            00
# Distant                                            00
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            00
# Distant                                            10
# Distant                                            98
# Distant                                            98
# Distant                                            99
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            98
# Distant                                            99
# Distant                                            98
# Distant                                            00
# Distant                                            98
# Distant                                            99
# Distant                                            98
#
# [1100 rows x 21 columns]

# %%
radiation_vc.order().plot(kind='barh')

plt.title('Radiation Statistics for ' + str(sum(radiation_vc)) + ' UPS')
# Out:
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':

# %%
spread_vc = ups['SEER historic stage A'].value_counts().drop(['Unstaged', 'Blank(s)', 'Localized/regional (Prostate cases)'])

# %%
labels = spread_vc.index.values
fracs = spread_vc.values
colors = sns.color_palette("deep", 3)

pie(fracs, labels=labels, shadow=True, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
# Out:
# (-1.0008787296463777,
#  1.0284872379382475,
#  -1.0017314562187316,
#  1.0000000101662017)

# %% [markdown]
# ### Survival Analysis

# %%
filt_ups = ups[ups['Survival months'] != 'Unknown']
filt_ups['Survival_months'] = filt_ups['Survival months'].astype(int)
filt_ups['censored'] = filt_ups['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})
# Out:
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)

data = filt_ups
kmf.fit(data['Survival_months'], data['censored'], label='All UPS (n=' + str(len(data)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

plt.xlim([0,120])
plt.ylim([0,1])

plt.title('UPS Survival All Patients')
plt.xlabel('Months')
plt.ylabel('Proportion Surviving')

# %%
localized_ups = filt_ups[filt_ups['SEER historic stage A'] == 'Localized']

# %%
non_rad_df = localized_ups[localized_ups['Radiation sequence with surgery'] == 'No radiation and/or cancer-directed surgery']
rad_df = localized_ups[localized_ups['Radiation sequence with surgery'] != 'No radiation and/or cancer-directed surgery']

fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)

data = rad_df
kmf.fit(data['Survival_months'], data['censored'], label='Radiation Given (n=' + str(len(data)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

data2 = non_rad_df
kmf.fit(data2['Survival_months'], data2['censored'], label='Radiation Not Given (n=' + str(len(data2)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

plt.xlim([0,120])
plt.ylim([0,1])

results = logrank_test(data['Survival_months'], data2['Survival_months'], data['censored'], data2['censored'], alpha=.95 )
results.print_summary()

plt.title('Localized UPS Survival Stratified by Radiation Given')
plt.xlabel('Months')
plt.ylabel('Proportion Surviving')
plt.text(10, 0.3, 'p = ' + '{0:.4f}'.format(results.p_value), size=12)
# Out:
# Results
#    df: 1
#    alpha: 0.95
#    t 0: -1
#    test: logrank
#    null distribution: chi squared
#
#    __ p-value ___|__ test statistic __|____ test result ____|__ is significant __
#          0.00223 |              9.353 |      Reject Null    |        True

# %% [markdown]
# ### Getting T Stage

# %%
concat_t_stage = (ups['Derived AJCC T, 7th ed (2010+)'] + ups['Derived AJCC T, 6th ed (2004+)'] + ups['T value - based on AJCC 3rd (1988-2003)']).dropna()

def getTStage(line):
    if line == np.nan:
        return np.nan
    m = re.match('.*(T[0-9]).*', line)
    if m == None:
        return np.nan
    else:
        return m.group(1)
    
t_stage_map = concat_t_stage.map(getTStage).dropna()

# %%
t1_pts = t_stage_map[t_stage_map == 'T1'].index.values
t2_pts = t_stage_map[t_stage_map == 'T2'].index.values

# %%
filt_ups = ups[ups['Survival months'] != 'Unknown']
filt_ups['Survival_months'] = filt_ups['Survival months'].astype(int)
filt_ups['censored'] = filt_ups['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})
# Out:
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)

data = filt_ups.ix[t1_pts]
kmf.fit(data['Survival_months'], data['censored'], label='T1 (n=' + str(len(data)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

data2 = filt_ups.ix[t2_pts]
kmf.fit(data2['Survival_months'], data2['censored'], label='T2 (n=' + str(len(data2)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

plt.xlim([0,120])
plt.ylim([0,1])

results = logrank_test(data['Survival_months'], data2['Survival_months'], data['censored'], data2['censored'], alpha=.95 )
results.print_summary()

plt.title('UPS Survival by T Stage')
plt.xlabel('Months')
plt.ylabel('Proportion Surviving')
plt.text(10, 0.3, 'p = ' + str(results.p_value), size=12)
# Out:
# Results
#    df: 1
#    alpha: 0.95
#    t 0: -1
#    test: logrank
#    null distribution: chi squared
#
#    __ p-value ___|__ test statistic __|____ test result ____|__ is significant __
#          0.00000 |            148.217 |      Reject Null    |        True

# %% [markdown]
# ### Age survival curves
