# %%
import pandas as pd
import numpy as np
from statsmodels.duration.hazard_regression import PHReg

import re

import seaborn as sns

sns.set_style('white')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Lifelines stuff
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
from lifelines.statistics import multivariate_logrank_test
from lifelines.statistics import pairwise_logrank_test

kmf = KaplanMeierFitter()

# %%
freq = pd.read_csv('./Data/sarcoma_frequencies.txt', sep='\t')
freq.Count = freq.Count.map(lambda x: int(x.replace(',', '')))

# %%
metastatic_survival = pd.read_csv('./Data/metastatic_sarcoma_survival.txt', sep='\t', index_col=0)
local_survival = pd.read_csv('./Data/localized_sarcoma_survival.txt', sep='\t', index_col=0)
local_location = pd.read_csv('./Data/localized_sarcoma_location.txt', sep='\t', index_col=0)

metastatic_survival['age'] = metastatic_survival['Age recode with single ages and 85+'].map(lambda x: int(re.match('([0-9]+).+', x).group(1)))

# %% [markdown]
# ## Metastatic Sarcoma

# %%
histology = 'leiomyosarcoma'
cutoff = 20

specific_histology = metastatic_survival[metastatic_survival['ICD-O-3 Hist/behav, malignant'].map(lambda x: histology in x.lower())]
specific_histology_available = specific_histology[specific_histology['Survival months'] != 'Unknown']

counts = specific_histology_available['ICD-O-3 Hist/behav, malignant'].value_counts()
count_index = counts[counts > cutoff].index.values

filt_hist = specific_histology_available.set_index('ICD-O-3 Hist/behav, malignant').ix[count_index]
filt_hist['Survival months'] = filt_hist['Survival months'].astype(int)
filt_hist['censored'] = filt_hist['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})

# %%
fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)


for tumor_type in filt_hist.index.unique():

    data = filt_hist.ix[tumor_type]
    kmf.fit(data['Survival months'], data['censored'], label=tumor_type +  "(n=" + str(len(data)) + ")")
    kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=True)
    
plt.xlim([0,60])
# Out:
# (0, 60)

# %% [markdown]
# ### Combine most common counts

# %%
common_types = ['leiomyosarcoma', 'hemangiosarcoma', 'spindle cell', 'giant cell', 'malignant fibrous histiocytoma', 'synovial', 'rhabdomyosarcoma', 'epithelioid', 'desmoplastic small round cell', 'ewing', 'alveolar soft part', 'liposarcoma']

def mapSarcomaType(line):
    for hist in common_types:
        if hist in line.lower():
            return hist
    
    return 'none'

# %%
filt_ms = metastatic_survival.copy()
filt_ms['histology_filt'] = metastatic_survival['ICD-O-3 Hist/behav, malignant'].map(mapSarcomaType)
filt_ms = filt_ms[filt_ms.histology_filt != 'none']
filt_ms = filt_ms[filt_ms['Survival months'] != 'Unknown']

filt_ms['Survival months'] = filt_ms['Survival months'].astype(int)
filt_ms['censored'] = filt_ms['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})

# %%
sns.set_palette(sns.color_palette("hls", 12))

ms_gby = filt_ms.groupby('histology_filt')

fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)

median_survival = []

for name, group in ms_gby:
    median_survival.append([name, group['Survival months'].median()])

survival_order = pd.DataFrame(zip(*median_survival)).T.sort(1, ascending=False)[0].values
    
for name in survival_order:

    group = filt_ms.set_index('histology_filt').ix[name]
    kmf.fit(group['Survival months'], group['censored'], label=name +  " (n=" + str(len(group)) + ")")
    kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)
    
plt.xlim([0,120])
# Out:
# C:\Users\namqb\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# (0, 120)

# %% [markdown]
# ### Fitting Cox PH

# %% [markdown]
# ## Localized Sarcoma

# %%
local_survival['ICD-O-3 Hist/behav, malignant'].value_counts()
# Out:
# 8890/3: Leiomyosarcoma, NOS                           6717
# 8830/3: Malignant fibrous histiocytoma                4154
# 8800/3: Sarcoma, NOS                                  2539
# 8851/3: Liposarcoma, well differentiated              2046
# 8852/3: Myxoid liposarcoma                            1601
# 9120/3: Hemangiosarcoma                               1562
# 8811/3: Fibromyxosarcoma                              1536
# 8802/3: Giant cell sarcoma                            1512
# 8832/3: Dermatofibrosarcoma, NOS                      1250
# 8801/3: Spindle cell sarcoma                          1218
# 9540/3: Malignant peripheral nerve sheath tumor       1092
# 8850/3: Liposarcoma, NOS                               973
# 8858/3: Dedifferentiated liposarcoma                   801
# 8810/3: Fibrosarcoma, NOS                              614
# 9040/3: Synovial sarcoma, NOS                          571
# 8854/3: Pleomorphic liposarcoma                        557
# 9041/3: Synovial sarcoma, spindle cell                 553
# 8805/3: Undifferentiated sarcoma                       472
# 8804/3: Epithelioid sarcoma                            397
# 9043/3: Synovial sarcoma, biphasic                     336
# 9150/3: Hemangiopericytoma, malignant                  328
# 9231/3: Myxoid chondrosarcoma                          276
# 8891/3: Epithelioid leiomyosarcoma                     246
# 8982/3: Malignant myoepithelioma                       236
# 9220/3: Chondrosarcoma, NOS                            234
# 8840/3: Myxosarcoma                                    224
# 9260/3: Ewing sarcoma                                  223
# 8855/3: Mixed liposarcoma                              218
# 8815/3: Solitary fibrous tumor, malignant              216
# 8900/3: Rhabdomyosarcoma, NOS                          189
#                                                       ...
# 8902/3: Mixed type rhabdomyosarcoma                     14
# 8860/3: Angiomyoliposarcoma                             14
# 8983/3: Adenomyoepithelioma, malignant                  12
# 9243/3: Dedifferentiated chondrosarcoma                 11
# 8857/3: Fibroblastic liposarcoma                        11
# 8836/3: Malignant angiomatoid fibrous histiocytoma       9
# 9042/3: Synovial sarcoma, epithelioid cell               9
# 8842/3: Ossifying fibromyxoid tumor, malignant           9
# 9365/3: Askin tumor                                      7
# 9170/3: Lymphangiosarcoma                                7
# 9571/3: Perineurioma, malignant                          6
# 8814/3: Infantile fibrosarcoma                           5
# 9182/3: Fibroblastic osteosarcoma                        5
# 8835/3: Malignant plexiform fibrohistiocytic tumor       3
# 9242/3: Clear cell chondrosarcoma                        2
# 8821/3: Aggressive fibromatosis, malignant               2
# 9183/3: Telangiectatic osteosarcoma                      2
# 9185/3: Small cell osteosarcoma                          2
# 9230/3: Chondroblastoma, malignant                       2
# 9372/3: Dedifferentiated chordoma                        1
# 8893/3: Bizarre leiomyosarcoma                           1
# 9186/3: Central osteosarcoma                             1
# 8841/3: Angiomyxoma, malignant                           1
# 9192/3: Parosteal osteosarcoma                           1
# 9250/3: Giant cell tumor of bone, malignant              1
# 9194/3: High grade surface osteosarcoma                  1
# 9125/3: Epithelioid hemangiosarcoma                      1
# 8824/3: Myofibroma, malignant                            1
# 8813/3: Fascial fibrosarcoma                             1
# 9124/3: Kupffer cell sarcoma                             1
# Name: ICD-O-3 Hist/behav, malignant, dtype: int64

# %%
histology = 'Malignant peripheral nerve sheath tumor'

specific_histology = local_survival[local_survival['ICD-O-3 Hist/behav, malignant'].map(lambda x: histology.lower() in x.lower())]
specific_histology_available = specific_histology[specific_histology['Survival months'] != 'Unknown']

filt_hist = specific_histology_available.set_index('ICD-O-3 Hist/behav, malignant')
filt_hist['Survival months'] = filt_hist['Survival months'].astype(int)
filt_hist['censored'] = filt_hist['Vital status recode (study cutoff used)'].map({'Dead':1, 'Alive':0})

# %%
radiation_given = ['Beam radiation', 'Combination of beam with implants or isotopes', 'Radioactive implants', 'Radiation, NOS method or source not specified']

rad_df = filt_hist[filt_hist.Radiation.map(lambda x: x in radiation_given)]
non_rad_df = filt_hist[~filt_hist.Radiation.map(lambda x: x in radiation_given)]

fig = plt.figure(figsize=(8, 6)) 
ax = plt.subplot(1,1,1)

data = rad_df
kmf.fit(data['Survival months'], data['censored'], label='Radiation Given (n=' + str(len(data)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

data2 = non_rad_df
kmf.fit(data2['Survival months'], data2['censored'], label='Radiation Not Given (n=' + str(len(data2)) + ")")
kmf.plot(ax=ax, ci_show=False, linewidth=1, show_censors=False)

plt.xlim([0,120])
plt.ylim([0,1])
# Out:
# (0, 1)

# %% [markdown]
# ## Synovial Sarcoma Location

# %%
def mapLocation(line):
    line = line.lower()
    if 'limb' in line:
        return 'extremity'
    elif 'trunk' in line:
        return 'trunk'
    elif 'pelvis' in line:
        return 'trunk'
    elif ('thorax' in line) | ('lung' in line):
        return 'lung'
    else:
        return line

# %%
vc = local_location['Primary Site - labeled'].map(mapLocation).value_counts()

# %%
vc/vc.sum()
# Out:
# extremity                                                     0.638474
# lung                                                          0.112903
# trunk                                                         0.074744
# c49.0-conn, subcutaneous, other soft tis: head, face, neck    0.042486
# c49.4-conn, subcutaneous, other soft tis: abdomen             0.031078
# c49.9-conn, subcutaneous and other soft tissues, nos          0.014162
# c64.9-kidney, nos                                             0.009048
# c38.4-pleura, nos                                             0.008261
# c80.9-unknown primary site                                    0.006294
# c48.0-retroperitoneum                                         0.005901
# c38.0-heart                                                   0.004721
# c38.3-mediastinum, nos                                        0.003934
# c07.9-parotid gland                                           0.003147
# c38.2-posterior mediastinum                                   0.002360
# c32.1-supraglottis                                            0.002360
# c73.9-thyroid gland                                           0.001967
# c38.1-anterior mediastinum                                    0.001967
# c49.8-overlap conn, subcutaneous, and other soft tissues      0.001967
# c14.0-pharynx, nos                                            0.001967
# c31.0-maxillary sinus                                         0.001967
# c41.4-pelvic bones, sacrum, coccyx and associated joints      0.001574
# c22.0-liver                                                   0.001574
# c41.2-vertebral column                                        0.001574
# c06.0-cheek mucosa                                            0.001180
# c09.9-tonsil, nos                                             0.001180
# c13.9-hypopharynx, nos                                        0.001180
# c30.0-nasal cavity                                            0.001180
# c48.1-specified parts of peritoneum                           0.000787
# c33.9-trachea                                                 0.000787
# c38.8-overlapping lesion of heart, mediastinum and pleura     0.000787
#                                                                 ...
# c63.1-spermatic cord                                          0.000393
# c31.1-ethmoid sinus                                           0.000393
# c41.8-overlap bones, joints, and art. cartilage               0.000393
# c03.0-upper gum                                               0.000393
# c32.9-larynx, nos                                             0.000393
# c71.8-overlapping lesion of brain                             0.000393
# c72.9-nervous system, nos                                     0.000393
# c03.1-lower gum                                               0.000393
# c17.9-small intestine, nos                                    0.000393
# c16.5-lesser curvature of stomach nos                         0.000393
# c41.3-rib, sternum, clavicle and associated joints            0.000393
# c47.9-autonomic nervous system, nos                           0.000393
# c17.2-ileum                                                   0.000393
# c13.2-posterior wall of hypopharynx                           0.000393
# c50.4-upper-outer quadrant of breast                          0.000393
# c11.9-nasopharynx, nos                                        0.000393
# c18.0-cecum                                                   0.000393
# c32.3-laryngeal cartilage                                     0.000393
# c05.1-soft palate, nos                                        0.000393
# c12.9-pyriform sinus                                          0.000393
# c13.8-overlapping lesion of hypopharynx                       0.000393
# c41.9-bone, nos                                               0.000393
# c10.9-oropharynx, nos                                         0.000393
# c69.6-orbit, nos                                              0.000393
# c50.2-upper-inner quadrant of breast                          0.000393
# c11.1-posterior wall of nasopharynx                           0.000393
# c16.2-body of stomach                                         0.000393
# c70.1-spinal meninges                                         0.000393
# c08.1-sublingual gland                                        0.000393
# c16.6-greater curvature of stomach nos                        0.000393
# Name: Primary Site - labeled, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-06369fb2356c> in <module>()
# ----> 1 vc.sum() + 'f'
#
# TypeError: unsupported operand type(s) for +: 'long' and 'str'
